# %%
import numpy as np
import pandas as pd
import os
os.chdir("/Users/shuozhang/Desktop/data")
may=pd.read_csv('maydataall.csv', sep='\t', index_col=False)

# %%
may1 = may.loc[map(lambda x,y: x >=(-75) and x<=(-72) and y >= 40 and y <= 41.5, \
                  may.Lon, may.Lat),:]

# %%
print may.shape
print may1.shape
# Out:
# (16847979, 11)
# (16492221, 11)

# %%
may1.index=range(0, may1.shape[0])

# %%
may1.head()
# Out:
#             Date  Distance        Lat        Lon Payment  Tip  Total    Type  \
# 0  2014-05-31-17      2.22  40.760120 -73.987040     CSH  0.0   11.0  yellow
# 1  2014-05-29-13      0.82  40.734602 -73.983312     CRD  1.9   11.9  yellow
# 2  2014-05-29-13      0.86  40.745145 -73.989925     CRD  1.6   10.1  yellow
# 3  2014-05-30-11      3.38  40.735587 -73.985630     CSH  0.0   14.5  yellow
# 4  2014-05-31-16      1.04  40.750152 -73.987915     CSH  0.0    9.0  yellow
#
#    Temp  Rain  Snow
# 0  69.0   0.0     0
# 1  54.0   0.0     0
# 2  54.0   0.0     0
# 3  59.0   0.0     0
# 4  71.0   0.0     0

# %%
may1["Lat"] = may1["Lat"].astype(str)
may1["Lon"] = may1["Lon"].astype(str)
# Out:
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
may1['Lat1']=map(lambda x: x[0:6], may1['Lat'])
# Out:
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
may1['Lon1']=map(lambda x: x[0:7], may1['Lon'])
# Out:
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
may1["Coord"] =may1[["Lat1", "Lon1"]].apply(lambda x: ",".join(x), axis=1)
# Out:
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
# print len(set(may1["Coord"]))
# print len(may1["Coord"])
# Out:
# 49372
# 16492221

# %%
may1.to_csv('mayzip1.csv', sep='\t', encoding='utf-8', index_col=False)

# %%
apr=pd.read_csv('aprdataall.csv', sep='\t', index_col=False)

# %%
apr1 = apr.loc[map(lambda x,y: x >=(-75) and x<=(-72) and y >= 40 and y <= 41.5, \
                  apr.Lon, apr.Lat),:]

# %%
apr1.index=range(0, apr1.shape[0])

# %%
apr1["Lat"] = apr1["Lat"].astype(str)
apr1["Lon"] = apr1["Lon"].astype(str)
# Out:
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
apr1['Lat1']=map(lambda x: x[0:6], apr1['Lat'])
apr1['Lon1']=map(lambda x: x[0:7], apr1['Lon'])
# Out:
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
apr1["Coord"] =apr1[["Lat1", "Lon1"]].apply(lambda x: ",".join(x), axis=1)
# Out:
# /Users/shuozhang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
print apr.shape
print apr1.shape
# Out:
# (16492430, 11)
# (16192580, 14)

# %%
apr1.to_csv('aprzip1.csv', sep='\t', encoding='utf-8', index_col=False)

# %%
june=pd.read_csv('jundataall.csv', sep='\t', index_col=False)

# %%
june=june.drop(june[june.Lon==0.0].index)
june=june.drop(june[june.Lat==0.0].index)
june.index=range(0, june.shape[0])

# %%
june["Lat"] = june["Lat"].astype(str)
june["Lon"] = june["Lon"].astype(str)
june['Lat1']=map(lambda x: x[0:6], june['Lat'])
june['Lon1']=map(lambda x: x[0:7], june['Lon'])

# %%
june["Coord"] =june[["Lat1", "Lon1"]].apply(lambda x: ",".join(x), axis=1)

# %%
june.to_csv('junezip1.csv', sep='\t', encoding='utf-8', index_col=False)

# %%
july=pd.read_csv('julydataall.csv', sep='\t', index_col=False)

# %%
july=july.drop(july[july.Lon==0.0].index)
july=july.drop(july[july.Lat==0.0].index)
july.index=range(0, july.shape[0])
july["Lat"] = july["Lat"].astype(str)
july["Lon"] = july["Lon"].astype(str)
july['Lat1']=map(lambda x: x[0:6], july['Lat'])
july['Lon1']=map(lambda x: x[0:7], july['Lon'])
july["Coord"] =july[["Lat1", "Lon1"]].apply(lambda x: ",".join(x), axis=1)

# %%
july.to_csv('julyzip1.csv', sep='\t', encoding='utf-8', index_col=False)

# %%
aug=pd.read_csv('augdataall.csv', sep='\t', index_col=False)
aug=aug.drop(aug[aug.Lon==0.0].index)
aug=aug.drop(aug[aug.Lat==0.0].index)
aug.index=range(0, aug.shape[0])
aug["Lat"] = aug["Lat"].astype(str)
aug["Lon"] = aug["Lon"].astype(str)
aug['Lat1']=map(lambda x: x[0:6], aug['Lat'])
aug['Lon1']=map(lambda x: x[0:7], aug['Lon'])
aug["Coord"] =aug[["Lat1", "Lon1"]].apply(lambda x: ",".join(x), axis=1)

# %%
aug.to_csv('augzip1.csv', sep='\t', encoding='utf-8', index_col=False)

# %%
sep=pd.read_csv('sepdataall.csv', sep='\t', index_col=False)
sep=sep.drop(sep[sep.Lon==0.0].index)
sep=sep.drop(sep[sep.Lat==0.0].index)
sep.index=range(0, sep.shape[0])
sep["Lat"] = sep["Lat"].astype(str)
sep["Lon"] = sep["Lon"].astype(str)
sep['Lat1']=map(lambda x: x[0:6], sep['Lat'])
sep['Lon1']=map(lambda x: x[0:7], sep['Lon'])
sep["Coord"] =sep[["Lat1", "Lon1"]].apply(lambda x: ",".join(x), axis=1)

# %%
sep.to_csv('sepzip1.csv', sep='\t', encoding='utf-8', index_col=False)

# %%
# import numpy as np
# import pandas as pd
# import os
# os.chdir("/Users/shuozhang/Desktop/capstone")
# apr=pd.read_csv('aprzip1.csv', sep='\t', index_col=False)
# may=pd.read_csv('mayzip1.csv', sep='\t', index_col=False)
# june=pd.read_csv('junezip1.csv', sep='\t', index_col=False)
# july=pd.read_csv('julyzip1.csv', sep='\t', index_col=False)
# aug=pd.read_csv('augzip1.csv', sep='\t', index_col=False)
# sep=pd.read_csv('sepzip1.csv', sep='\t', index_col=False)

# %%
import numpy as np
ls=np.concatenate((apr["Coord"],may["Coord"], june["Coord"], july["Coord"],\
                   aug["Coord"], sep["Coord"]), axis=0)

# %%
len(set(ls))

# %%
df=pd.DataFrame(list(set(ls)))

# %%
df.shape

# %%
df.to_csv('coord2.csv', sep='\t', encoding='utf-8', index_col=False)

# %%
ls1=ls[0:1000]

# %%
ls2=ls[1000:10000]

# %%
output=pd.read_csv('zipcode_output.csv', sep=',', index_col=False)

# %%
output.shape
# Out:
# (20000, 3)

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(0,1000):
   location = geolocator.reverse(ls1[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls1[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(0,775):
   location = geolocator.reverse(ls2[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls2[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])
# Out:
# 40.816,-73.604,11545
# 40.520,-74.090,10306
# 40.796,-74.473,07960
# 40.796,-74.472,07960
# 40.796,-74.475,07960
# 40.796,-74.474,07960
# 40.796,-74.477,07960
# 41.090,-74.308,07456
# 40.753,-73.785,11358
# 40.644,-73.835,11693
# 40.882,-73.433,11743
# 40.618,-73.929,11234
# 40.618,-73.928,11234
# 40.618,-73.927,11234
# 40.618,-73.926,11234
# 40.618,-73.925,11234
# 40.618,-73.924,11234
# 40.618,-73.923,11234
# 40.618,-73.922,11234
# 40.618,-73.921,11234
# 40.618,-73.920,11234
# 40.945,-73.818,10707
# 40.945,-73.819,10707
# 40.668,-74.106,07002
# 40.753,-73.782,11358
# 40.813,-73.900,10455
# 40.813,-73.901,10455
# 40.813,-73.902,10455
# 40.813,-73.903,10455
# 40.813,-73.904,10455
# 40.813,-73.905,10455
# 40.813,-73.906,10455
# 40.813,-73.907,10455
# 40.813,-73.908,10455
# 40.813,-73.909,10455
# 41.004,-73.763,10606
# 40.688,-73.986,11217
# 40.688,-73.987,11201
# 41.004,-73.764,10606
# 40.861,-74.041,07606
# 40.861,-74.042,07606
# 40.832,-73.879,10472
# 40.688,-73.982,11217
# ...

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(775,9000):
   location = geolocator.reverse(ls2[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls2[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])
# Out:
# 41.098,-74.506,
# 40.842,-73.878,10460
# 40.842,-73.879,10460
# 40.842,-73.872,10460
# 40.842,-73.873,10460
# 40.842,-73.870,10460
# 40.842,-73.871,10460
# 40.842,-73.876,10460
# 40.842,-73.877,10460
# 40.842,-73.874,10460
# 40.842,-73.875,10462
# 40.874,-73.985,07605
# 40.725,-73.85,11375
# 40.725,-73.87,11379
# 40.763,-73.753,11362
# 40.763,-73.752,11362
# 40.725,-73.82,11367
# 40.763,-73.750,11030
# 36.352,-54.266,NaN
# 40.874,-73.989,07605
# 40.892,-74.222,07512
# 40.892,-74.221,07512
# 40.763,-73.758,11361
# 40.610,-73.996,11214
# 40.610,-73.997,11214
# 40.610,-73.995,11214
# 40.610,-73.992,11214
# 41.058,-73.914,10960
# 40.610,-73.990,11204
# 40.610,-73.991,11214
# 40.761,-74.055,07307
# 40.698,-73.675,11010
# 40.610,-73.998,11214
# 40.610,-73.999,11214
# 40.755,-73.800,11358
# 40.755,-73.801,11358
# 40.895,-73.913,10471
# 40.755,-73.803,11358
# 40.895,-73.915,10471
# 40.895,-73.914,10471
# 40.755,-73.806,11358
# 40.755,-73.807,11358
# 40.726,-74.074,07306
# ...

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(3071,9000):
   location = geolocator.reverse(ls2[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls2[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])
# Out:
# 40.697,-73.995,11201
# 40.697,-73.994,11201
# 40.697,-73.997,11201
# 40.697,-73.996,11201
# 40.668,-73.838,11417
# 43.935,-76.530,
# 40.761,-74.039,07087
# 40.761,-74.038,07087
# 40.668,-73.834,11417
# 41.004,-73.791,10583
# 40.668,-73.836,11417
# 40.668,-73.837,11417
# 40.761,-74.033,07087
# 40.761,-74.032,07087
# 40.761,-74.031,07307
# 40.761,-74.030,07307
# 40.838,-73.721,11050
# 40.734,-73.085,11782
# 41.049,-73.702,10577
# 40.708,-74.092,07305
# 40.708,-74.093,07305
# 40.642,-74.001,11220
# 40.792,-73.494,11791
# 40.708,-74.094,07305
# 40.708,-74.095,07305
# 40.794,-74.254,07052
# 40.781,-73.613,11568
# 40.826,-73.738,11024
# 41.035,-73.809,10530
# 40.805,-74.209,07042
# 40.718,-73.733,11429
# 40.718,-73.736,11001
# 40.718,-73.735,11429
# 40.718,-73.734,11429
# 40.666,-74.350,07090
# 40.666,-74.351,07092
# 40.718,-73.738,11428
# 40.663,-74.247,07203
# 40.663,-74.240,07202
# 40.663,-74.249,07203
# 40.964,-73.718,10528
# 40.853,-73.93,10040
# 40.853,-73.96,07010
# ...

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(3422,9000):
   location = geolocator.reverse(ls2[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls2[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])
# Out:
# 41.030,-73.712,10577
# 40.747,-73.799,11365
# 41.030,-73.714,10577
# 40.723,-73.934,11222
# 40.640,-74.607,07920
# 40.816,-74.446,07927
# 40.964,-74.237,07470
# 40.715,-73.739,11429
# 40.756,-73.715,11004
# 40.756,-73.714,11004
# 40.847,-73.86,10462
# 40.799,-73.969,10025
# 50.467,-69.196,
# 40.661,-73.748,11413
# 40.914,-73.960,07670
# 40.914,-73.961,07670
# 40.914,-73.962,07670
# 40.914,-73.963,07670
# 40.791,-73.659,11576
# 40.567,-74.385,08820
# 40.766,-73.726,11362
# 40.905,-74.180,07501
# 40.791,-73.653,11577
# 40.791,-73.656,11577
# 40.688,-73.645,11552
# 40.913,-74.051,07601
# 40.838,-73.743,11024
# 40.739,-74.224,07106
# 40.661,-73.742,11422
# 40.74,-74.03,07030
# 40.596,-74.376,08820
# 40.698,-73.645,11552
# 40.661,-73.741,11422
# 40.777,-74.067,07094
# 40.777,-74.066,07094
# 40.777,-74.069,07094
# 40.777,-74.068,07094
# 40.850,-74.001,07650
# 40.850,-74.000,07650
# 40.850,-74.003,07650
# 40.845,-73.863,10462
# 40.970,-73.796,10583
# 40.844,-73.940,10032
# ...

# %%
ls3=ls[10000:20000]

# %%
len(ls3)
# Out:
# 10000

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(0,3000):
   location = geolocator.reverse(ls3[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls3[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])
# Out:
# 40.702,-73.795,11433
# 40.839,-73.9,10457
# 40.702,-73.797,11433
# 40.702,-73.790,11433
# 40.702,-73.791,11433
# 40.702,-73.792,11433
# 40.502,-74.453,08901
# 40.702,-73.798,11433
# 40.702,-73.799,11451
# 40.912,-74.144,07504
# 40.742,-74.278,07040
# 40.72,-73.948,11222
# 40.605,-73.930,11234
# 40.72,-73.944,11222
# 40.72,-73.945,11222
# 40.72,-73.946,11222
# 40.72,-73.947,11222
# 40.72,-73.940,11222
# 40.72,-73.941,11222
# 40.742,-74.276,07040
# 40.72,-73.943,11222
# 40.661,-73.798,11430
# 40.661,-73.799,11430
# 40.661,-73.794,11430
# 40.661,-73.795,11430
# 40.661,-73.796,11430
# 40.661,-73.797,11430
# 40.661,-73.790,11434
# 40.661,-73.791,11430
# 40.661,-73.792,11430
# 40.661,-73.793,11430
# 40.601,-73.666,11558
# 40.872,-73.864,10467
# 37.271,-70.314,NaN
# 40.872,-73.865,10467
# 40.761,-73.777,11361
# 40.761,-73.775,11361
# 40.761,-73.774,11361
# 13.024,-103.25,NaN
# 40.761,-73.771,11361
# 40.761,-73.770,11361
# 40.656,-73.997,11232
# 40.822,-74.151,07110
# 40.822,-74.156,07110
# ...

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(3000,6000):
   location = geolocator.reverse(ls3[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls3[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])
# Out:
# 40.698,-74.006,10004
# 40.741,-73.793,11365
# 40.741,-73.792,11365
# 40.741,-73.791,11365
# 21.476,-76.335,
# 40.741,-73.797,11365
# 40.762,-73.961,10065
# 40.762,-73.960,10065
# 40.762,-73.963,10065
# 40.762,-73.962,10065
# 40.762,-73.965,10065
# 40.762,-73.964,10065
# 40.762,-73.967,10022
# 40.762,-73.966,10022
# 40.689,-73.705,11003
# 40.762,-73.968,10022
# 40.689,-73.707,11003
# 40.689,-73.706,11003
# 40.918,-74.064,07607
# 40.689,-73.702,11003
# 40.617,-73.736,11559
# 41.050,-73.542,06902
# 41.050,-73.547,06902
# 40.671,-74.044,10004
# 40.657,-73.98,11218
# 40.651,-74.641,07921
# 40.615,-74.008,11228
# 40.615,-74.009,11228
# 40.615,-74.006,11228
# 40.852,-73.687,11050
# 40.615,-74.004,11228
# 40.615,-74.005,11228
# 40.615,-74.002,11214
# 40.615,-74.003,11228
# 40.615,-74.000,11214
# 40.615,-74.001,11214
# 41.043,-73.982,10962
# 41.043,-73.980,10962
# 40.732,-73.451,11735
# 40.727,-73.571,11530
# 40.727,-73.577,11530
# 40.769,-73.729,11362
# 40.747,-73.569,11590
# ...

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv
geolocator = Nominatim()
zipcode = []
zipcode_all = []

for n in range(6000,10000):
   location = geolocator.reverse(ls3[n], timeout=50)
   if location.address == None:
       zipcode = "NaN"
   else:
       num = str(re.findall(r"\D(\d{5})\D", location.address))
       num = str(filter(str.isdigit, num))
       zipcode = num
   output = str(ls3[n]) + "," + zipcode
   print output
   time.sleep(1)
   with open(r"zipcode_output.csv", 'a') as f:
       writer = csv.writer(f,delimiter='\t')
       writer.writerow([output])
# Out:
# 40.643,-73.963,11226
# 40.728,-73.427,11735
# 40.629,-73.998,11219
# 40.629,-73.999,11219
# 40.728,-73.422,11735
# 40.654,-73.892,11207
# 40.629,-73.992,11219
# 40.629,-73.993,11219
# 40.629,-73.990,11219
# 40.629,-73.991,11219
# 40.629,-73.996,11219
# 40.629,-73.997,11219
# 40.629,-73.994,11219
# 40.629,-73.995,11219
# 40.826,-73.885,10459
# 40.989,-73.710,10528
# 40.826,-73.887,10459
# 40.826,-73.886,10459
# 40.826,-73.881,10472
# 40.826,-73.880,10472
# 40.826,-73.883,10472
# 40.826,-73.882,10472
# 40.676,-74.195,07201
# 40.743,-74.0,10011
# 40.826,-73.888,10459
# 40.702,-73.958,11211
# 40.702,-73.959,11249
# 40.69,-74.187,07201
# 40.69,-74.186,07201
# 40.69,-74.185,07201
# 40.69,-74.184,07114
# 40.702,-73.952,11206
# 40.702,-73.953,11206
# 40.702,-73.950,11206
# 40.702,-73.951,11206
# 40.702,-73.956,11211
# 40.702,-73.957,11211
# 40.702,-73.954,11206
# 40.702,-73.955,11206
# 40.933,-73.889,10701
# 40.952,-73.991,07628
# 40.835,-73.442,11743
# 41.061,-74.286,07465
# ...
